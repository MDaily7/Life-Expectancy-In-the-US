# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
survey_data17_df = pd.read_csv("DataBase Materials/OSMI Mental Health in Tech Survey 2017.csv")
survey_data16_df = pd.read_csv("DataBase Materials/mental-heath-in-tech-2016_20161114.csv")
survey_data14_df = pd.read_csv("DataBase Materials/Mental Health in Tech Survey (Responses) - Form Responses 1.csv")

# %%
# check the df shape for each dataset
survey_data17_df.shape
# Out:
# (756, 123)

# %%
survey_data16_df.shape
# Out:
# (1433, 63)

# %%
survey_data14_df.shape
# Out:
# (1260, 27)

# %%
# List the colist(survey_data14_df.columns.values)
# Out:
# ['Timestamp',
#  'Age',
#  'Gender',
#  'Country',
#  'If you live in the United States, which state or territory do you live in?',
#  'Are you self-employed?',
#  'Do you have a family history of mental illness?',
#  'Have you sought treatment for a mental health condition?',
#  'If you have a mental health condition, do you feel that it interferes with your work?',
#  'How many employees does your company or organization have?',
#  'Do you work remotely (outside of an office) at least 50% of the time?',
#  'Is your employer primarily a tech company/organization?',
#  'Does your employer provide mental health benefits?',
#  'Do you know the options for mental health care your employer provides?',
#  'Has your employer ever discussed mental health as part of an employee wellness program?',
#  'Does your employer provide resources to learn more about mental health issues and how to seek help?',
# ...

# %%
list(survey_data16_df.columns.values)
# Out:
# ['Are you self-employed?',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health concerns and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:',
# ...

# %%
list(survey_data17_df.columns.values)
# Out:
# ['#',
#  '<strong>Are you self-employed?</strong>',
#  'How many employees does your company or organization have?',
#  'Is your employer primarily a tech company/organization?',
#  'Is your primary role within your company related to tech/IT?',
#  'Does your employer provide mental health benefits\xa0as part of healthcare coverage?',
#  'Do you know the options for mental health care available under your employer-provided health coverage?',
#  'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?',
#  'Does your employer offer resources to learn more about mental health disorders and options for seeking help?',
#  'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?',
#  'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?',
# ...

# %%
clean_data14_df = survey_data14_df.iloc[: , [1, 2, 3, 4, 5, 6, 7, 9, 11, 12, 13, 14, 15, 16, 17, 20, 21, 22, 23, 25]].copy()
clean_data14_df.head()
# Out:
#    Age  Gender         Country  \
# 0   37  Female   United States
# 1   44       M   United States
# 2   32    Male          Canada
# 3   31    Male  United Kingdom
# 4   31    Male   United States
#
#   If you live in the United States, which state or territory do you live in?  \
# 0                                                 IL
# 1                                                 IN
# 2                                                NaN
# 3                                                NaN
# 4                                                 TX
#
#   Are you self-employed? Do you have a family history of mental illness?  \
# 0                    NaN                                              No
# 1                    NaN                                              No
# 2                    NaN                                              No
# 3                    NaN                                             Yes
# ...

# %%
clean_data14_df.shape
# Out:
# (1260, 20)

# %%
clean_data16_df = survey_data16_df.iloc[: , [0,1,2,4,5,6,7,8,9,12,13,15,36,38,45,52,55,56,57,58]].copy()
clean_data16_df.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# ...

# %%
clean_data16_df.shape
# Out:
# (1433, 20)

# %%
clean_data17_df = survey_data17_df.iloc[: , [1,2,3,5,6,7,8,9,10,12,15,90,91,96,98,104,112,113,114,115]].copy()
clean_data17_df.head()
# Out:
#    <strong>Are you self-employed?</strong>  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        1
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
# 3                                     More than 1000
# 4                                                NaN
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                NaN
#
# ...

# %%
clean_data17_df.shape
# Out:
# (756, 20)

# %%
age_check = clean_data14_df.Age.value_counts()
age_check
# Out:
#  29             85
#  32             82
#  26             75
#  27             71
#  33             70
#  28             68
#  31             67
#  34             65
#  30             63
#  25             61
#  35             55
#  23             51
#  24             46
#  37             43
#  38             39
#  36             37
#  40             33
#  39             33
#  43             28
#  41             22
#  22             21
#  42             20
#  21             16
#  45             12
#  46             12
#  44             11
#  19              9
#  18              7
#  48              6
#  50              6
#  20              6
#  51              5
#  49              4
#  56              4
#  57              3
#  54              3
#  55              3
#  47              2
#  60              2
#  99999999999     1
#  5               1
# -1               1
#  11              1
#  8               1
#  61              1
#  53              1
# -29              1
# ...

# %%
clean_data14_df = clean_data14_df[(clean_data14_df['Age'] > 17) & (clean_data14_df['Age'] < 81)]
clean_data14_df
# Out:
#       Age  Gender         Country  \
# 0      37  Female   United States
# 1      44       M   United States
# 2      32    Male          Canada
# 3      31    Male  United Kingdom
# 4      31    Male   United States
# ...   ...     ...             ...
# 1255   32    Male   United States
# 1256   34    male   United States
# 1257   46       f   United States
# 1258   25    Male   United States
# 1259   41    Male       Australia
#
#      If you live in the United States, which state or territory do you live in?  \
# 0                                                    IL
# 1                                                    IN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    TX
# ...                                                 ...
# 1255                                                 IL
# 1256                                                 CA
# ...

# %%
clean_data14_df['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
clean_data16_df = clean_data16_df[(clean_data16_df['What is your age?'] > 17) & (clean_data16_df['What is your age?'] < 81)]
clean_data16_df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                  6-25
# 2                                                  6-25
# 3                                                   NaN
# 4                                                  6-25
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# ...

# %%
clean_data16_df['What is your age?'].hist()
# Out:
# <AxesSubplot:>

# %%
clean_data17_df = clean_data17_df[(clean_data17_df['What is your age?'] > 17) & (clean_data17_df['What is your age?'] < 81)]
clean_data17_df
# Out:
#      <strong>Are you self-employed?</strong>  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          1
# ..                                       ...
# 749                                        0
# 750                                        0
# 751                                        0
# 752                                        0
# 754                                        0
#
#     How many employees does your company or organization have?  \
# 0                                              100-500
# 1                                              100-500
# 2                                                 6-25
# 3                                       More than 1000
# 4                                                  NaN
# ..                                                 ...
# ...

# %%
clean_data17_df['What is your age?'].hist()
# Out:
# <AxesSubplot:>

# %%
emp_num14 = clean_data14_df['How many employees does your company or organization have?'].value_counts()
emp_num14
# Out:
# 6-25              289
# 26-100            288
# More than 1000    281
# 100-500           175
# 1-5               158
# 500-1000           61
# Name: How many employees does your company or organization have?, dtype: int64

# %%
emp_num16 = clean_data16_df['How many employees does your company or organization have?'].value_counts()
emp_num16
# Out:
# 26-100            292
# More than 1000    255
# 100-500           247
# 6-25              208
# 500-1000           80
# 1-5                60
# Name: How many employees does your company or organization have?, dtype: int64

# %%
emp_num17 = clean_data17_df['How many employees does your company or organization have?'].value_counts()
emp_num17
# Out:
# 100-500           203
# More than 1000    158
# 26-100            128
# 6-25               86
# 500-1000           48
# 1-5                20
# Name: How many employees does your company or organization have?, dtype: int64

# %%
gender14 = clean_data14_df.Gender.value_counts()
gender14
# Out:
# Male                                              613
# male                                              204
# Female                                            121
# M                                                 116
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Woman                                               3
# Male                                                3
# Female                                              2
# Cis Male                                            2
# Man                                                 2
# Female (trans)                                      2
# Malr                                                1
# Trans woman                                         1
# ...

# %%
gender16 = clean_data16_df['What is your gender?'].value_counts()
gender16
# Out:
# Male           608
# male           247
# Female         153
# female          95
# M               86
#               ...
# Human            1
# Genderfluid      1
# Enby             1
# Malr             1
# MALE             1
# Name: What is your gender?, Length: 69, dtype: int64

# %%
gender17 = clean_data17_df['What is your gender?'].value_counts()
gender17
# Out:
# Male                                                         328
# Female                                                       108
# male                                                         102
# female                                                        63
# M                                                             27
# m                                                             23
# F                                                             16
# f                                                             13
# Male                                                           6
# Nonbinary                                                      4
# Woman                                                          4
# Man                                                            3
# Female                                                         3
# woman                                                          2
# ...

# %%
# convert all string values in gender columns to lower case in clean2014df
clean_data14_df['Gender'] = clean_data14_df['Gender'].apply(str.lower)
clean_data14_df['Gender'].value_counts()
# Out:
# male                                              817
# female                                            183
# m                                                 150
# f                                                  53
# woman                                               4
# make                                                4
# male                                                3
# cis male                                            3
# female                                              2
# man                                                 2
# female (trans)                                      2
# msle                                                1
# male leaning androgynous                            1
# trans woman                                         1
# queer                                               1
# neuter                                              1
# cis-female/femme                                    1
# ...

# %%
# convert all values to string
clean_data16_df['What is your gender?'] = clean_data16_df['What is your gender?'].astype('string')
clean_data16_df['What is your gender?'].value_counts()
# Out:
# Male                 608
# male                 247
# Female               153
# female                95
# M                     86
#                     ...
# Cis Male               1
# cisdude                1
# Genderqueer            1
# Male (trans, FtM)      1
# MALE                   1
# Name: What is your gender?, Length: 69, dtype: Int64

# %%
# fill in na with a space
clean_data16_df['What is your gender?'].fillna('', inplace=True)

# %%
# convert all string values in gender columns to lower case in clean2014df
clean_data16_df['What is your gender?'] = clean_data16_df['What is your gender?'].apply(str.lower)
clean_data16_df['What is your gender?'].value_counts()
# Out:
# male                                                                                                                                                             856
# female                                                                                                                                                           248
# m                                                                                                                                                                165
# f                                                                                                                                                                 61
# male                                                                                                                                                              13
# ...

# %%
# convert all values to string
clean_data17_df['What is your gender?'] = clean_data17_df['What is your gender?'].astype('string')
clean_data17_df['What is your gender?'].value_counts()
# Out:
# Male                                                         328
# Female                                                       108
# male                                                         102
# female                                                        63
# M                                                             27
# m                                                             23
# F                                                             16
# f                                                             13
# Male                                                           6
# Nonbinary                                                      4
# Woman                                                          4
# Female                                                         3
# Man                                                            3
# woman                                                          2
# ...

# %%
# fill in na with a space
clean_data17_df['What is your gender?'].fillna('', inplace=True)

# %%
# convert all string values in gender columns to lower case in clean2014df
clean_data17_df['What is your gender?'] = clean_data17_df['What is your gender?'].apply(str.lower)
clean_data17_df['What is your gender?'].value_counts()
# Out:
# male                                                         430
# female                                                       171
# m                                                             50
# f                                                             29
#                                                               11
# woman                                                          6
# male                                                           6
# nonbinary                                                      5
# man                                                            4
# cis-male                                                       3
# female                                                         3
# cis male                                                       2
# genderqueer/non-binary                                         1
# female (cis)                                                   1
# ...
